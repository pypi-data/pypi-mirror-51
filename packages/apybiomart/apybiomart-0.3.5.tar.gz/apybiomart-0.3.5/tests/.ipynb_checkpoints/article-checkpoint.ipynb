# %% [markdown]
# # Asynchronous queries on BioMart using `apybiomart`

# %% [markdown]
# [BioMart](https://www.ensembl.org/biomart/martview) is a web-based tool that allows to retrieve and export datasets from Ensembl. It is one of the most useful resources for bioinformatics, because it makes easy to retrieve data and further analyse them or integrate them in downstream analyses. For these reasons, researchers have developed applications to perform BioMart queries from within R and Python programs, namely [biomaRt](https://bioconductor.org/packages/release/bioc/html/biomaRt.html) and [pybiomart](https://github.com/jrderuiter/pybiomart).
#
# I've been using both for different needs, and I was very happy with them. But lately I've been working on a database that needs to access many different online resources, and thus performs asynchronous requests (exploiting the great `asyncio` Python library). Since the database was developed in Python, I tried to use `pybiomart` for these tasks, but unfortunately it was not suitable to perform async calls, so I decided to modify it to better suit my needs, and that's when `apybiomart` was born!

# %% [markdown]
# What this package does is simply modifying the original `pybiomart` behaviour to retain its basic capabilities, extending them to handle asynchronous requests to the BioMart service. As such, it is possible to perform multiple queries at the same time.

# %% [markdown]
# ## Installation
# Apybiomart **only supports Python 3**, and can be installed through `pip`:
# ```bash
# pip install apybiomart
# ```

# %% [markdown]
# ## Usage
# After installation, apybiomart can be easily imported into Python:

# %%
import apybiomart

# %% [markdown]
# Now it is possible to use its functions:
#
# * explore the list of available marts, datasets, attributes and filters using the synchronous `find_*()` functions;
# * perform a single synchronous query using the `query()` function;
# * perform multiple asynchronous queries using the `aquery()` function.

# %% [markdown]
# ### Marts, datasets, attributes and filters
#
# BioMart contains different databases, called *marts*, each of which in turn contains several *datasets*, each related to a particular species. These datasets can be queried and it is possible to restrict the amount of data returned to one or more particular types of information, namely *attributes*, and using *filters* that only retain data satisfying one or more specific criteria (more information on BioMart's [help page](https://www.ensembl.org/info/data/biomart/index.html).
#
# This tutorial will mostly follow the outline available in the official [biomaRt users guide](https://www.bioconductor.org/packages/devel/bioc/vignettes/biomaRt/inst/doc/biomaRt.html).

# %% [markdown]
# #### Marts
#
# In order to view marts available on BioMart, use `find_marts()`; a dataframe with the available marts is returned, with their proper `name` and `display_name`:

# %%
apybiomart.find_marts()
# Out:
#                     name           display_name
# 0   ENSEMBL_MART_ENSEMBL       Ensembl Genes 96
# 1     ENSEMBL_MART_MOUSE       Mouse strains 96
# 2  ENSEMBL_MART_SEQUENCE               Sequence
# 3  ENSEMBL_MART_ONTOLOGY               Ontology
# 4   ENSEMBL_MART_GENOMIC    Genomic features 96
# 5       ENSEMBL_MART_SNP   Ensembl Variation 96
# 6   ENSEMBL_MART_FUNCGEN  Ensembl Regulation 96

# %% [markdown]
# #### Datasets
#
# Each BioMart database (or mart) can contain several different datasets, each referring to a particular species. The `find_datasets()` function allows to list all the available datasets for a given mart, which by default is "ENSEMBL_MART_ENSEMBL".

# %%
apybiomart.find_datasets()
# Out:
#                            name  \
# 0      uamericanus_gene_ensembl
# 1          ngalili_gene_ensembl
# 2        oprinceps_gene_ensembl
# 3        oanatinus_gene_ensembl
# 4           malbus_gene_ensembl
# 5      mnemestrina_gene_ensembl
# 6            catys_gene_ensembl
# 7          elucius_gene_ensembl
# 8           drerio_gene_ensembl
# 9      zalbicollis_gene_ensembl
# 10       lcoronata_gene_ensembl
# 11         cpugnax_gene_ensembl
# 12          bbison_gene_ensembl
# 13      mdomestica_gene_ensembl
# 14        jjaculus_gene_ensembl
# 15        hburtoni_gene_ensembl
# 16    acitrinellus_gene_ensembl
# 17     fdamarensis_gene_ensembl
# 18      cporcellus_gene_ensembl
# 19        olatipes_gene_ensembl
# 20      cchok1gshd_gene_ensembl
# 21      oniloticus_gene_ensembl
# 22        marmatus_gene_ensembl
# 23    mleucophaeus_gene_ensembl
# 24      xmaculatus_gene_ensembl
# 25           arowi_gene_ensembl
# 26      umaritimus_gene_ensembl
# 27           hmale_gene_ensembl
# 28       mmusculus_gene_ensembl
# 29     rnorvegicus_gene_ensembl
# ..                          ...
# 154     ipunctatus_gene_ensembl
# 155         dordii_gene_ensembl
# 156         pmajor_gene_ensembl
# 157         mzebra_gene_ensembl
# 158     choffmanni_gene_ensembl
# 159     pcoquereli_gene_ensembl
# 160       hsapiens_gene_ensembl
# 161       celegans_gene_ensembl
# 162   sboliviensis_gene_ensembl
# 163       apercula_gene_ensembl
# 164      etelfairi_gene_ensembl
# 165    mspicilegus_gene_ensembl
# 166        chircus_gene_ensembl
# 167     rroxellana_gene_ensembl
# 168        panubis_gene_ensembl
# 169        mcaroli_gene_ensembl
# 170      clanigera_gene_ensembl
# 171   atestudineus_gene_ensembl
# 172         vpacos_gene_ensembl
# 173      pcapensis_gene_ensembl
# 174      spartitus_gene_ensembl
# 175     ttruncatus_gene_ensembl
# 176   mochrogaster_gene_ensembl
# 177  acarolinensis_gene_ensembl
# 178       smaximus_gene_ensembl
# 179       tguttata_gene_ensembl
# 180       cpygmaea_gene_ensembl
# 181       neugenii_gene_ensembl
# 182     pnattereri_gene_ensembl
# 183     ccapucinus_gene_ensembl
#
#                                           display_name                  mart
# 0              American black bear genes (ASM334442v1)  ENSEMBL_MART_ENSEMBL
# 1    Upper Galilee mountains blind mole rat genes (...  ENSEMBL_MART_ENSEMBL
# 2                           Pika genes (OchPri2.0-Ens)  ENSEMBL_MART_ENSEMBL
# 3                               Platypus genes (OANA5)  ENSEMBL_MART_ENSEMBL
# 4                        Swamp eel genes (M_albus_1.0)  ENSEMBL_MART_ENSEMBL
# 5                  Pig-tailed macaque genes (Mnem_1.0)  ENSEMBL_MART_ENSEMBL
# 6                      Sooty mangabey genes (Caty_1.0)  ENSEMBL_MART_ENSEMBL
# 7                        Northern pike genes (Eluc_V3)  ENSEMBL_MART_ENSEMBL
# 8                             Zebrafish genes (GRCz11)  ENSEMBL_MART_ENSEMBL
# 9    White-throated sparrow genes (Zonotrichia_albi...  ENSEMBL_MART_ENSEMBL
# 10   Blue-crowned manakin genes (Lepidothrix_corona...  ENSEMBL_MART_ENSEMBL
# 11                            Ruff genes (ASM143184v1)  ENSEMBL_MART_ENSEMBL
# 12                 American bison genes (Bison_UMD1.0)  ENSEMBL_MART_ENSEMBL
# 13                             Opossum genes (monDom5)  ENSEMBL_MART_ENSEMBL
# 14            Lesser Egyptian jerboa genes (JacJac1.0)  ENSEMBL_MART_ENSEMBL
# 15             Burton's mouthbrooder genes (AstBur1.0)  ENSEMBL_MART_ENSEMBL
# 16                      Midas cichlid genes (Midas_v5)  ENSEMBL_MART_ENSEMBL
# 17                    Damara mole rat genes (DMR_v1.0)  ENSEMBL_MART_ENSEMBL
# 18                        Guinea Pig genes (Cavpor3.0)  ENSEMBL_MART_ENSEMBL
# 19            Japanese medaka HdrR genes (ASM223467v1)  ENSEMBL_MART_ENSEMBL
# 20        Chinese hamster CHOK1GS genes (CHOK1GS_HDv1)  ENSEMBL_MART_ENSEMBL
# 21                           Tilapia genes (Orenil1.0)  ENSEMBL_MART_ENSEMBL
# 22                      Zig-zag eel genes (fMasArm1.1)  ENSEMBL_MART_ENSEMBL
# 23                           Drill genes (Mleu.le_1.0)  ENSEMBL_MART_ENSEMBL
# 24              Platyfish genes (X_maculatus-5.0-male)  ENSEMBL_MART_ENSEMBL
# 25                  Okarito brown kiwi genes (aptRow1)  ENSEMBL_MART_ENSEMBL
# 26                       Polar bear genes (UrsMar_1.0)  ENSEMBL_MART_ENSEMBL
# 27              Naked mole-rat male genes (HetGla_1.0)  ENSEMBL_MART_ENSEMBL
# 28                             Mouse genes (GRCm38.p6)  ENSEMBL_MART_ENSEMBL
# 29                                Rat genes (Rnor_6.0)  ENSEMBL_MART_ENSEMBL
# ..                                                 ...                   ...
# 154                 Channel catfish genes (IpCoco_1.2)  ENSEMBL_MART_ENSEMBL
# 155                      Kangaroo rat genes (Dord_2.0)  ENSEMBL_MART_ENSEMBL
# 156                   Great Tit genes (Parus_major1.1)  ENSEMBL_MART_ENSEMBL
# 157                  Zebra mbuna genes (M_zebra_UMD2a)  ENSEMBL_MART_ENSEMBL
# 158                              Sloth genes (choHof1)  ENSEMBL_MART_ENSEMBL
# 159                 Coquerel's sifaka genes (Pcoq_1.0)  ENSEMBL_MART_ENSEMBL
# 160                           Human genes (GRCh38.p12)  ENSEMBL_MART_ENSEMBL
# 161            Caenorhabditis elegans genes (WBcel235)  ENSEMBL_MART_ENSEMBL
# 162         Bolivian squirrel monkey genes (SaiBol1.0)  ENSEMBL_MART_ENSEMBL
# 163                   Orange clownfish genes (Nemo_v1)  ENSEMBL_MART_ENSEMBL
# 164              Lesser hedgehog tenrec genes (TENREC)  ENSEMBL_MART_ENSEMBL
# 165                       Steppe mouse genes (MUSP714)  ENSEMBL_MART_ENSEMBL
# 166                                  Goat genes (ARS1)  ENSEMBL_MART_ENSEMBL
# 167           Golden snub-nosed monkey genes (Rrox_v1)  ENSEMBL_MART_ENSEMBL
# 168                      Olive baboon genes (Panu_3.0)  ENSEMBL_MART_ENSEMBL
# 169               Ryukyu mouse genes (CAROLI_EIJ_v1.1)  ENSEMBL_MART_ENSEMBL
# 170           Long-tailed chinchilla genes (ChiLan1.0)  ENSEMBL_MART_ENSEMBL
# 171                  Climbing perch genes (fAnaTes1.1)  ENSEMBL_MART_ENSEMBL
# 172                             Alpaca genes (vicPac1)  ENSEMBL_MART_ENSEMBL
# 173                              Hyrax genes (proCap1)  ENSEMBL_MART_ENSEMBL
# 174  Bicolor damselfish genes (Stegastes_partitus-1...  ENSEMBL_MART_ENSEMBL
# 175                            Dolphin genes (turTru1)  ENSEMBL_MART_ENSEMBL
# 176                     Prairie vole genes (MicOch1.0)  ENSEMBL_MART_ENSEMBL
# 177                     Anole lizard genes (AnoCar2.0)  ENSEMBL_MART_ENSEMBL
# 178                         Turbot genes (ASM318616v1)  ENSEMBL_MART_ENSEMBL
# 179                    Zebra Finch genes (taeGut3.2.4)  ENSEMBL_MART_ENSEMBL
# 180         Spoon-billed sandpiper genes (ASM369795v1)  ENSEMBL_MART_ENSEMBL
# 181                           Wallaby genes (Meug_1.0)  ENSEMBL_MART_ENSEMBL
# 182  Red-bellied piranha genes (Pygocentrus_nattere...  ENSEMBL_MART_ENSEMBL
# 183                Capuchin genes (Cebus_imitator-1.0)  ENSEMBL_MART_ENSEMBL
#
# [184 rows x 3 columns]

# %% [markdown]
# #### Attributes
#
# When querying one of BioMart's datasets, attributes define specific values we might be interested in retrieving, such as gene symbols or chromosomal coordinates. The `find_attributes()` function displays all available attributes in a given dataset, which by default is "hsapiens_gene_ensembl":

# %%
apybiomart.find_attributes()
# Out:
#                                    name  \
# 0                       ensembl_gene_id
# 1               ensembl_gene_id_version
# 2                 ensembl_transcript_id
# 3         ensembl_transcript_id_version
# 4                    ensembl_peptide_id
# 5            ensembl_peptide_id_version
# 6                       ensembl_exon_id
# 7                           description
# 8                       chromosome_name
# 9                        start_position
# 10                         end_position
# 11                               strand
# 12                                 band
# 13                     transcript_start
# 14                       transcript_end
# 15             transcription_start_site
# 16                    transcript_length
# 17                       transcript_tsl
# 18             transcript_gencode_basic
# 19                    transcript_appris
# 20               transcript_mane_select
# 21                   external_gene_name
# 22                 external_gene_source
# 23             external_transcript_name
# 24      external_transcript_source_name
# 25                     transcript_count
# 26           percentage_gene_gc_content
# 27                         gene_biotype
# 28                   transcript_biotype
# 29                               source
# ...                                 ...
# 3321        sequence_transcript_biotype
# 3322   sequence_transcript_chrom_strand
# 3323    sequence_transcript_chrom_start
# 3324      sequence_transcript_chrom_end
# 3325  sequence_transcription_start_site
# 3326            sequence_peptide_length
# 3327         sequence_transcript_length
# 3328               sequence_cdna_length
# 3329                  cdna_coding_start
# 3330                    cdna_coding_end
# 3331                        5_utr_start
# 3332                          5_utr_end
# 3333                        3_utr_start
# 3334                          3_utr_end
# 3335            sequence_exon_stable_id
# 3336                      sequence_type
# 3337          sequence_exon_chrom_start
# 3338            sequence_exon_chrom_end
# 3339         sequence_exon_chrom_strand
# 3340                      sequence_rank
# 3341                     sequence_phase
# 3342                 sequence_end_phase
# 3343         sequence_cdna_coding_start
# 3344           sequence_cdna_coding_end
# 3345      sequence_genomic_coding_start
# 3346        sequence_genomic_coding_end
# 3347              sequence_constitutive
# 3348                         cds_length
# 3349                          cds_start
# 3350                            cds_end
#
#                                     display_name  \
# 0                                 Gene stable ID
# 1                         Gene stable ID version
# 2                           Transcript stable ID
# 3                   Transcript stable ID version
# 4                              Protein stable ID
# 5                      Protein stable ID version
# 6                                 Exon stable ID
# 7                               Gene description
# 8                       Chromosome/scaffold name
# 9                                Gene start (bp)
# 10                                 Gene end (bp)
# 11                                        Strand
# 12                                Karyotype band
# 13                         Transcript start (bp)
# 14                           Transcript end (bp)
# 15                Transcription start site (TSS)
# 16    Transcript length (including UTRs and CDS)
# 17                Transcript support level (TSL)
# 18                      GENCODE basic annotation
# 19                             APPRIS annotation
# 20                       RefSeq match transcript
# 21                                     Gene name
# 22                           Source of gene name
# 23                               Transcript name
# 24                     Source of transcript name
# 25                              Transcript count
# 26                             Gene % GC content
# 27                                     Gene type
# 28                               Transcript type
# 29                                 Source (gene)
# ...                                          ...
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329                     CDS start (within cDNA)
# 3330                       CDS end (within cDNA)
# 3331                                5' UTR start
# 3332                                  5' UTR end
# 3333                                3' UTR start
# 3334                                  3' UTR end
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341                                 start phase
# 3342                                   end phase
# 3343                           cDNA coding start
# 3344                             cDNA coding end
# 3345                        Genomic coding start
# 3346                          Genomic coding end
# 3347
# 3348                                  CDS Length
# 3349                                   CDS start
# 3350                                     CDS end
#
#                                             description                dataset
# 0                                 Stable ID of the Gene  hsapiens_gene_ensembl
# 1                      Versionned stable ID of the Gene  hsapiens_gene_ensembl
# 2                           Stable ID of the Transcript  hsapiens_gene_ensembl
# 3                Versionned stable ID of the Transcript  hsapiens_gene_ensembl
# 4                                                        hsapiens_gene_ensembl
# 5                                                        hsapiens_gene_ensembl
# 6                                                        hsapiens_gene_ensembl
# 7                                                        hsapiens_gene_ensembl
# 8                              Chromosome/scaffold name  hsapiens_gene_ensembl
# 9     Start Coordinate of the gene in chromosomal co...  hsapiens_gene_ensembl
# 10    End Coordinate of the gene in chromosomal coor...  hsapiens_gene_ensembl
# 11         Orientation of genes on chromosome/scaffold.  hsapiens_gene_ensembl
# 12       Band of chromosome/scaffold where genes occur.  hsapiens_gene_ensembl
# 13    Start Coordinate of the transcript in chromoso...  hsapiens_gene_ensembl
# 14    End Coordinate of the gene in chromosomal coor...  hsapiens_gene_ensembl
# 15                                                       hsapiens_gene_ensembl
# 16                                                       hsapiens_gene_ensembl
# 17                                                       hsapiens_gene_ensembl
# 18                                                       hsapiens_gene_ensembl
# 19                                                       hsapiens_gene_ensembl
# 20                                                       hsapiens_gene_ensembl
# 21                                                       hsapiens_gene_ensembl
# 22                                                       hsapiens_gene_ensembl
# 23                                                       hsapiens_gene_ensembl
# 24                                                       hsapiens_gene_ensembl
# 25                                                       hsapiens_gene_ensembl
# 26                           Percentage gene GC content  hsapiens_gene_ensembl
# 27                                                       hsapiens_gene_ensembl
# 28                                                       hsapiens_gene_ensembl
# 29                                                       hsapiens_gene_ensembl
# ...                                                 ...                    ...
# 3321                                                     hsapiens_gene_ensembl
# 3322                                                     hsapiens_gene_ensembl
# 3323                                                     hsapiens_gene_ensembl
# 3324                                                     hsapiens_gene_ensembl
# 3325                                                     hsapiens_gene_ensembl
# 3326                                                     hsapiens_gene_ensembl
# 3327                                                     hsapiens_gene_ensembl
# 3328                                                     hsapiens_gene_ensembl
# 3329                                                     hsapiens_gene_ensembl
# 3330                                                     hsapiens_gene_ensembl
# 3331                                                     hsapiens_gene_ensembl
# 3332                                                     hsapiens_gene_ensembl
# 3333                                                     hsapiens_gene_ensembl
# 3334                                                     hsapiens_gene_ensembl
# 3335                                                     hsapiens_gene_ensembl
# 3336                                                     hsapiens_gene_ensembl
# 3337                                                     hsapiens_gene_ensembl
# 3338                                                     hsapiens_gene_ensembl
# 3339                                                     hsapiens_gene_ensembl
# 3340                                                     hsapiens_gene_ensembl
# 3341                                                     hsapiens_gene_ensembl
# 3342                                                     hsapiens_gene_ensembl
# 3343                                                     hsapiens_gene_ensembl
# 3344                                                     hsapiens_gene_ensembl
# 3345                                                     hsapiens_gene_ensembl
# 3346                                                     hsapiens_gene_ensembl
# 3347                                                     hsapiens_gene_ensembl
# 3348                                                     hsapiens_gene_ensembl
# 3349                                                     hsapiens_gene_ensembl
# 3350                                                     hsapiens_gene_ensembl
#
# [3351 rows x 4 columns]

# %% [markdown]
# #### Filters
#
# Filters, on the other hand, can be used to define a restriction on a query, such as retrieving only results from chromosome X. All available filters for a given dataset can be displayed using the `find_filters()` function, which by default will use the "hsapiens_gene_ensembl" dataset:

# %%
apybiomart.find_filters()
# Out:
#                                           name                    type  \
# 0                         link_so_mini_closure                    list
# 1                              link_go_closure                    text
# 2            link_ensembl_transcript_stable_id                    text
# 3                                      gene_id                    text
# 4                                transcript_id                    text
# 5                         link_ensembl_gene_id                    text
# 6                              chromosome_name                    text
# 7                                        start                    text
# 8                                          end                    text
# 9                                   band_start  drop_down_basic_filter
# 10                                    band_end  drop_down_basic_filter
# 11                                marker_start  drop_down_basic_filter
# 12                                  marker_end
# 13                        hsapiens_encode.type                    text
# 14               hsapiens_encode.encode_region
# 15                                      strand                    text
# 16                          chromosomal_region                    text
# 17                       id_list_xrefs_filters            boolean_list
# 18                 id_list_limit_xrefs_filters                 id_list
# 19                  id_list_microarray_filters            boolean_list
# 20            id_list_limit_microarray_filters                 id_list
# 21               transcript_count_greater_than                    text
# 22                  transcript_count_less_than                    text
# 23                                     biotype                    list
# 24                          transcript_biotype                    list
# 25                                      source                    list
# 26                           transcript_source                    list
# 27                              transcript_tsl                 boolean
# 28                    transcript_gencode_basic                 boolean
# 29                           transcript_appris                 boolean
# 30                                 mane_select                 boolean
# 31                       phenotype_description                    list
# 32                            phenotype_source                    list
# 33                                     go_clos
# 34                                     go_name
# 35                            go_evidence_code                    list
# 36                             homolog_filters            boolean_list
# 37  id_list_protein_domain_and_feature_filters            boolean_list
# 38        id_list_limit_protein_domain_filters                 id_list
# 39                  germ_line_variation_source                    list
# 40                    somatic_variation_source                    list
# 41                          with_validated_snp                 boolean
# 42                         so_consequence_name                    list
#
#                                           description                dataset
# 0                                                      hsapiens_gene_ensembl
# 1                                                      hsapiens_gene_ensembl
# 2                                                      hsapiens_gene_ensembl
# 3                                                      hsapiens_gene_ensembl
# 4                                                      hsapiens_gene_ensembl
# 5   Filter to include genes with supplied list of ...  hsapiens_gene_ensembl
# 6                                                      hsapiens_gene_ensembl
# 7   Determine which base pair on the specified chr...  hsapiens_gene_ensembl
# 8   Determine which base pair on the specified chr...  hsapiens_gene_ensembl
# 9                                                      hsapiens_gene_ensembl
# 10                                                     hsapiens_gene_ensembl
# 11                                                     hsapiens_gene_ensembl
# 12                                                     hsapiens_gene_ensembl
# 13                                                     hsapiens_gene_ensembl
# 14                                                     hsapiens_gene_ensembl
# 15                                                     hsapiens_gene_ensembl
# 16  Limit to Genes within multiple comma separate ...  hsapiens_gene_ensembl
# 17                                                     hsapiens_gene_ensembl
# 18                                                     hsapiens_gene_ensembl
# 19                                                     hsapiens_gene_ensembl
# 20                                                     hsapiens_gene_ensembl
# 21  Limit to genes within given Transcript Count r...  hsapiens_gene_ensembl
# 22  Limit to genes within given Transcript Count r...  hsapiens_gene_ensembl
# 23                                                     hsapiens_gene_ensembl
# 24                                                     hsapiens_gene_ensembl
# 25                                                     hsapiens_gene_ensembl
# 26                                                     hsapiens_gene_ensembl
# 27                                                     hsapiens_gene_ensembl
# 28                                                     hsapiens_gene_ensembl
# 29                                                     hsapiens_gene_ensembl
# 30                                                     hsapiens_gene_ensembl
# 31                                                     hsapiens_gene_ensembl
# 32                                                     hsapiens_gene_ensembl
# 33                                                     hsapiens_gene_ensembl
# 34                                                     hsapiens_gene_ensembl
# 35                                                     hsapiens_gene_ensembl
# 36                                                     hsapiens_gene_ensembl
# 37                                                     hsapiens_gene_ensembl
# 38                                                     hsapiens_gene_ensembl
# 39                                                     hsapiens_gene_ensembl
# 40                                                     hsapiens_gene_ensembl
# 41  Entries associated with variants that have bee...  hsapiens_gene_ensembl
# 42                                                     hsapiens_gene_ensembl
